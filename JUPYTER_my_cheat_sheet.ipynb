# %% [markdown]
# ***
# # --- CHEAT SHEET ---
# ***
# ***

# %% [markdown]
# ## Markdown
# - Horizontal line: <code>***</code>
# ***

# %% [markdown]
# ## Common Shortcuts
#
# - Auto suggest function arguments
#     <code> Shift + TAB
#
# - Collapse cell
#     <code> Click the blue vertical bar in front of the cell
#
# - Comment/Uncomment block of code
#     <code> CTRL + /
#
# - Indent/Unindent
#     <code>SHIFT + [</code> or <code>SHIFT + ]

# %% [markdown]
# ***
# ## How to save as html without cell input?
#
# File --> New --> Terminal
#
# <code> jupyter nbconvert '.\xyz\path\to\notebook.ipynb' --to html --no-input

# %% [markdown]
# ***
# ## Insert image
#
# Create a markodwn cell, drag & drop the image
#
# - how to resize: see https://stackoverflow.com/questions/41598916/resize-the-image-in-jupyter-notebook-using-markdown
#
#     <
#     <code>img src="image.JPG" alt="Drawing" style="width: 200px;"/></code>

# %% [markdown]
# ***
# ## View all variables

# %% [markdown]
# <code> %who </code>
#     or for more information
#     <code> %whos

# %% [markdown]
# ***
# ## print numbers with specified format

# %% [markdown]
# use <code> 'string %1.1f' % radius

# %% [markdown]
# ***
# ## Reset Variables via code ...

# %% [markdown]
# use <code>%reset -f

# %% [markdown]
# ***
# ## Matplotlib in notebook or external window
#
# <code>%matplotlib inline
# <code>%matplotlib qt

# %% [markdown]
# ***
# ## How to copy image to clipboard?
# hold <code>SHIFT</code> while right clicking the image

# %% [markdown]
# ---
# ## Change font size with
#
#     <font size=5>

# %% [markdown]
# ***
# ## Get conda info
#
# <code> !conda info </code>

# %% [markdown]
# ---

# %% [markdown]
# # Test section

# %% [markdown]
# # test
#
# <font size=5>
# how big is this
#
# $\omega$ is xyz
#
#     - abc
# - def

# %%
# !conda info
# Out:
#      active environment : notebook
#     active env location : /srv/conda/envs/notebook
#             shell level : 1
#        user config file : /home/jovyan/.condarc
#  populated config files : /srv/conda/.condarc
#           conda version : 4.9.2
#     conda-build version : not installed
#          python version : 3.8.6.final.0
#        virtual packages : __glibc=2.27=0
#                           __unix=0=0
#                           __archspec=1=x86_64
#        base environment : /srv/conda  (writable)
#            channel URLs : https://conda.anaconda.org/conda-forge/linux-64
#                           https://conda.anaconda.org/conda-forge/noarch
#                           https://repo.anaconda.com/pkgs/main/linux-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/linux-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#           package cache : /srv/conda/pkgs
# ...
